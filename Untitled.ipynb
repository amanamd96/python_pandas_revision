# %% [markdown]
# # Lets download and read the IMDB dataset to work with pandas
#   File1: https://drive.google.com/file/d/1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd/view?usp=sharing
#  File2: https://drive.google.com/file/d/1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm/view?usp=sharing

# %%
import numpy as np 
import pandas as pd

# %%
movies = pd.read_csv("movies.csv")
directors =  pd.read_csv("directors.csv")

# %%
movies.head()
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# ...

# %%
directors.head()
# Out:
#    Unnamed: 0      director_name    id gender
# 0           0      James Cameron  4762   Male
# 1           1     Gore Verbinski  4763   Male
# 2           2         Sam Mendes  4764   Male
# 3           3  Christopher Nolan  4765   Male
# 4           4     Andrew Stanton  4766   Male

# %%
movies.shape
# Out:
# (1465, 12)

# %%
directors.shape
# Out:
# (2349, 4)

# %% [markdown]
# # Approach 1: Row-oriented
#             It takes 2 arguments
#             A list of rows
#             A list of column names/labels

# %%
data = pd.DataFrame(
    [
        ["A" , 20 , "Mumbai"],
        ["B" , 30 , "Pune"],
        ["C" , 40 , "UP"]
    ],
    columns = ["Name" , "Age" , "City"]
)

# %%
data
# Out:
#   Name  Age    City
# 0    A   20  Mumbai
# 1    B   30    Pune
# 2    C   40      UP

# %% [markdown]
# # COLUMN BASED

# %%
data2 = pd.DataFrame({
    "Name" : ["A", "B" , "C"],
    "Age" : [10 , 20 , 30],
    "City" : ["Mumbai" , "Pune" , "UP"]
})

# %%
data2
# Out:
#   Name  Age    City
# 0    A   10  Mumbai
# 1    B   20    Pune
# 2    C   30      UP

# %%
# data access using iloc(implicit indexing)

# %%
directors.head()
# Out:
#    Unnamed: 0      director_name    id gender
# 0           0      James Cameron  4762   Male
# 1           1     Gore Verbinski  4763   Male
# 2           2         Sam Mendes  4764   Male
# 3           3  Christopher Nolan  4765   Male
# 4           4     Andrew Stanton  4766   Male

# %%
directors.iloc[1]
# Out:
# Unnamed: 0                    1
# director_name    Gore Verbinski
# id                         4763
# gender                     Male
# Name: 1, dtype: object

# %%
# using loc (explicit)

# %%
directors.loc[1]
# Out:
# Unnamed: 0                    1
# director_name    Gore Verbinski
# id                         4763
# gender                     Male
# Name: 1, dtype: object

# %%
#access coluumn

directors["director_name"]
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4          Andrew Stanton
#               ...
# 2344        Shane Carruth
# 2345     Neill Dela Llana
# 2346          Scott Smith
# 2347          Daniel Hsia
# 2348     Brian Herzlinger
# Name: director_name, Length: 2349, dtype: object

# %%
#unique name and count
directors["director_name"].unique()
directors["director_name"].nunique()
# Out:
# 2349

# %%
#rename
directors.rename({"gender":"Gender"} , axis =1)  #if you want to change permanent write inplace = True
# Out:
#       Unnamed: 0      director_name    id Gender
# 0              0      James Cameron  4762   Male
# 1              1     Gore Verbinski  4763   Male
# 2              2         Sam Mendes  4764   Male
# 3              3  Christopher Nolan  4765   Male
# 4              4     Andrew Stanton  4766   Male
# ...          ...                ...   ...    ...
# 2344        2344      Shane Carruth  7106   Male
# 2345        2345   Neill Dela Llana  7107    NaN
# 2346        2346        Scott Smith  7108    NaN
# 2347        2347        Daniel Hsia  7109   Male
# 2348        2348   Brian Herzlinger  7110   Male
#
# [2349 rows x 4 columns]

# %%
movies.head()  #check first 5 rows data
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# ...

# %%
movies.rename({"vote_average" : "rating"} , axis = 1)  #rename vote_average to rating
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  rating  vote_count  \
# 0                                       Avatar     7.2       11800
# 1     Pirates of the Caribbean: At World's End     6.9        4500
# ...

# %%
#add a row

# %%
#directors.loc[len(directors.index)] = [1234 , "Aman" , "Male"]
directors.loc[len(directors.index)] =[1234 , "Aman" ,22, "Male"]
directors.tail()
# Out:
#       Unnamed: 0     director_name    id gender
# 2346        2346       Scott Smith  7108    NaN
# 2347        2347       Daniel Hsia  7109   Male
# 2348        2348  Brian Herzlinger  7110   Male
# 2349        1234              Aman    22   Male
# 2350        1234              Aman    22   Male

# %%
#remove rows
directors.drop([2349 , 2350] , axis = 0)
# Out:
#       Unnamed: 0      director_name    id gender
# 0              0      James Cameron  4762   Male
# 1              1     Gore Verbinski  4763   Male
# 2              2         Sam Mendes  4764   Male
# 3              3  Christopher Nolan  4765   Male
# 4              4     Andrew Stanton  4766   Male
# ...          ...                ...   ...    ...
# 2344        2344      Shane Carruth  7106   Male
# 2345        2345   Neill Dela Llana  7107    NaN
# 2346        2346        Scott Smith  7108    NaN
# 2347        2347        Daniel Hsia  7109   Male
# 2348        2348   Brian Herzlinger  7110   Male
#
# [2349 rows x 4 columns]

# %%
#remove col
directors.drop("Unnamed: 0"  , axis = 1)
# Out:
#           director_name    id gender
# 0         James Cameron  4762   Male
# 1        Gore Verbinski  4763   Male
# 2            Sam Mendes  4764   Male
# 3     Christopher Nolan  4765   Male
# 4        Andrew Stanton  4766   Male
# ...                 ...   ...    ...
# 2346        Scott Smith  7108    NaN
# 2347        Daniel Hsia  7109   Male
# 2348   Brian Herzlinger  7110   Male
# 2349               Aman    22   Male
# 2350               Aman    22   Male
#
# [2351 rows x 3 columns]

# %% [markdown]
# #merging 2 data frame
# Since we need all the rows for movies, but not all of those for directors, to know the details of each movies, hence we will use left join.

# %%
movies.head()
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# ...

# %%
director.head()
# Out:
#    Unnamed: 0      director_name    id gender
# 0           0      James Cameron  4762   Male
# 1           1     Gore Verbinski  4763   Male
# 2           2         Sam Mendes  4764   Male
# 3           3  Christopher Nolan  4765   Male
# 4           4     Andrew Stanton  4766   Male

# %%
data = movies.merge(directors ,  left_on = movies.director_id , right_on = directors.id , how = "left")

# %%
data
# Out:
#       key_0  Unnamed: 0_x   id_x     budget  popularity     revenue  \
# 0      4762             0  43597  237000000         150  2787965087
# 1      4763             1  43598  300000000         139   961000000
# 2      4764             2  43599  245000000         107   880674609
# 3      4765             3  43600  250000000         112  1084939099
# 4      4767             5  43602  258000000         115   890871626
# ...     ...           ...    ...        ...         ...         ...
# 1460   4809          4736  48363          0           3      321952
# 1461   5369          4743  48370      27000          19     3151130
# 1462   5148          4748  48375          0           7           0
# 1463   5535          4749  48376          0           3           0
# 1464   5097          4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# ...

# %%
data.head()
# Out:
#    key_0   id_x     budget  popularity     revenue  \
# 0   4762  43597  237000000         150  2787965087
# 1   4763  43598  300000000         139   961000000
# 2   4764  43599  245000000         107   880674609
# 3   4765  43600  250000000         112  1084939099
# 4   4767  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name gender
# 0         4762  2009   Dec  Thursday      James Cameron   Male
# 1         4763  2007   May  Saturday     Gore Verbinski   Male
# ...

# %%
data.shape
# Out:
# (1465, 14)

# %%
##How to find sum of revenue and budget per movie?

# %%
data["budget_revenue"] = data["revenue"] + data["budget"]

# %%
data
# Out:
#       key_0   id_x     budget  popularity     revenue  \
# 0      4762  43597  237000000         150  2787965087
# 1      4763  43598  300000000         139   961000000
# 2      4764  43599  245000000         107   880674609
# 3      4765  43600  250000000         112  1084939099
# 4      4767  43602  258000000         115   890871626
# ...     ...    ...        ...         ...         ...
# 1460   4809  48363          0           3      321952
# 1461   5369  48370      27000          19     3151130
# 1462   5148  48375          0           7           0
# 1463   5535  48376          0           3           0
# 1464   5097  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# ...

# %%
#sum of revenue and budget

# %%
#one way
data[["revenue" , "budget"]].apply(np.sum) #bux default axis is 0
# Out:
# revenue    209866997305
# budget      70353617179
# dtype: int64

# %%
#another way
print("revenue is :" , data["revenue"].sum())
# Out:
# revenue is : 209866997305

# %%
print("budget is :" , data["budget"].sum())
# Out:
# budget is : 70353617179

# %%
# revenue and budget of per movie
data[["revenue" , "budget"]].apply(np.sum , axis = 1) #bux default axis is 0
# Out:
# 0       3024965087
# 1       1261000000
# 2       1125674609
# 3       1334939099
# 4       1148871626
#            ...
# 1460        321952
# 1461       3178130
# 1462             0
# 1463             0
# 1464       2260920
# Length: 1465, dtype: int64

# %% [markdown]
# What does this axis mean in apply ?
# If axis = 0, it will apply to each column, if axis = 1, each row
# By default axis = 0
# => apply() can be applied on any dataframe along any particular axis

# %%
#How can I find profit per movie? # revenue - budget?

# %%
def calc_profit(x):
  return x["revenue"] - x["budget"]

data["profit"] = data[["revenue", "budget"]].apply(calc_profit, axis = 1)

# %% [raw]
# #grouping
# How can we know the number of movies released by a particular director, say, Christopher Nolan?

# %%
data.loc[data["director_name"] == "Christopher Nolan" ,["title"]].count()
# Out:
# title    8
# dtype: int64

# %%
data["director_name"].value_counts()
# Out:
# director_name
# Steven Spielberg      26
# Martin Scorsese       19
# Clint Eastwood        19
# Woody Allen           18
# Ridley Scott          16
#                       ..
# Tim Hill               5
# Jonathan Liebesman     5
# Roman Polanski         5
# Larry Charles          5
# Nicole Holofcener      5
# Name: count, Length: 199, dtype: int64

# %% [raw]
# How can you find the average popularity of each director?
# We will have to some group our rows director wise.
#
# What is Grouping ?
# Simply it could be understood through the terms - Split, apply, combine

# %%
data.groupby("director_name")['title'].count()
# Out:
# director_name
# Adam McKay                      6
# Adam Shankman                   8
# Alejandro González Iñárritu     6
# Alex Proyas                     5
# Alexander Payne                 5
#                                ..
# Wes Craven                     10
# Wolfgang Petersen               7
# Woody Allen                    18
# Zack Snyder                     7
# Zhang Yimou                     6
# Name: title, Length: 199, dtype: int64

# %%
grouped_data = data.groupby("director_name")['title'].count()

# %%
grouped_data
# Out:
# director_name
# Adam McKay                      6
# Adam Shankman                   8
# Alejandro González Iñárritu     6
# Alex Proyas                     5
# Alexander Payne                 5
#                                ..
# Wes Craven                     10
# Wolfgang Petersen               7
# Woody Allen                    18
# Zack Snyder                     7
# Zhang Yimou                     6
# Name: title, Length: 199, dtype: int64

# %%
grouped_data.head()
# Out:
# director_name
# Adam McKay                     6
# Adam Shankman                  8
# Alejandro González Iñárritu    6
# Alex Proyas                    5
# Alexander Payne                5
# Name: title, dtype: int64

# %%
grouped_data = data.groupby("director_name")['title'].count().reset_index()

# %%
grouped_data.head()
# Out:
#                  director_name  title
# 0                   Adam McKay      6
# 1                Adam Shankman      8
# 2  Alejandro González Iñárritu      6
# 3                  Alex Proyas      5
# 4              Alexander Payne      5

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.barplot(x = "director_name", y = "title" , data=grouped_data)
# Out:
# <Axes: xlabel='director_name', ylabel='title'>

# %%
sns.barplot(x = "director_name", y = "title" , data=grouped_data.head())
plt.xticks(rotation = 90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Adam McKay'),
#   Text(1, 0, 'Adam Shankman'),
#   Text(2, 0, 'Alejandro González Iñárritu'),
#   Text(3, 0, 'Alex Proyas'),
#   Text(4, 0, 'Alexander Payne')])

# %%
#Give me the first and the last year for each of the directors in which they have created a movie

# %%
data.groupby("director_name")["year"].aggregate(["min", "max"]).reset_index()
# Out:
#                    director_name   min   max
# 0                     Adam McKay  2004  2015
# 1                  Adam Shankman  2001  2012
# 2    Alejandro González Iñárritu  2000  2015
# 3                    Alex Proyas  1994  2016
# 4                Alexander Payne  1999  2013
# ..                           ...   ...   ...
# 194                   Wes Craven  1984  2011
# 195            Wolfgang Petersen  1981  2006
# 196                  Woody Allen  1977  2013
# 197                  Zack Snyder  2004  2016
# 198                  Zhang Yimou  2002  2014
#
# [199 rows x 3 columns]

# %% [raw]
# #group by filtering
# How we find details of the movies by high budget directors?
# Lets assume,
#
# high budget director -> any director with atleast one movie with budget >100M

# %%
data.groupby("director_name").filter(lambda x: x["budget"].max() > 100000000)
# Out:
#       key_0   id_x     budget  popularity     revenue  \
# 0      4762  43597  237000000         150  2787965087
# 1      4763  43598  300000000         139   961000000
# 2      4764  43599  245000000         107   880674609
# 3      4765  43600  250000000         112  1084939099
# 4      4767  43602  258000000         115   890871626
# ...     ...    ...        ...         ...         ...
# 1450   4845  48267     400000          33   100000000
# 1451   4813  48268     200000          13     4505922
# 1452   4936  48274          0           5     2611555
# 1458   4881  48335      60000          27     3221152
# 1460   4809  48363          0           3      321952
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# ...

# %%
Notice what's happening here?

We first group data by director and then use groupby().filter function
Groups are filtered if they do not satisfy the boolean criterion specified by function
This is called Group Based Filtering
